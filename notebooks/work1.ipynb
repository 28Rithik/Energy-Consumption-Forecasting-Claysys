# %%
import numpy as np
import pandas as pd

# %%
hourly_df = pd.read_csv("../data/processed/hourly_energy.csv")

# %%
hourly_df.shape
hourly_df.head()
# Out:
#        city meter          x_Timestamp  t_kWh
# 0  Bareilly  BR02  2019-07-10 00:00:00  0.405
# 1  Bareilly  BR02  2019-07-10 01:00:00  0.446
# 2  Bareilly  BR02  2019-07-10 02:00:00  0.447
# 3  Bareilly  BR02  2019-07-10 03:00:00  0.450
# 4  Bareilly  BR02  2019-07-10 04:00:00  0.454

# %%
print(hourly_df.shape)

print(hourly_df["meter"].nunique())

print(hourly_df["x_Timestamp"].min())

print(hourly_df["x_Timestamp"].max())
# Out:
# (1350625, 4)
# 84
# 2019-05-01 00:00:00
# 2021-10-31 23:00:00
