# %%
v = 6*6 + 6*5 + 6*4 + 6*3 + 6*2 + 6*1
print(v)
# Out:
# 126

# %%
import pandas as pd
import numpy as np

# %%
comparison = pd.DataFrame({
    "Model": ["Prophet", "SARIMA", "LSTM"],
    "MAE": [0.2181, 0.0874, 0.0380],
    "RMSE": [0.2684, 0.1360, 0.0739]
})

comparison.to_csv(
    "../reports/model_comparison.csv",
    index=False
)

comparison
# Out:
#      Model     MAE    RMSE
# 0  Prophet  0.2181  0.2684
# 1   SARIMA  0.0874  0.1360
# 2     LSTM  0.0380  0.0739
